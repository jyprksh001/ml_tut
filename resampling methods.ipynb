# %% [markdown]
# important points
#
# trainging error and test error

# %% [markdown]
# ## Understanding variance and bias

# %%
from IPython.display import Image
Image(filename='1.png')

# %% [markdown]
# Url: https://www.youtube.com/watch?v=_2ij6eaaSl0&list=PL5-da3qGB5IA6E6ZNXu7dp89_uv8yocmf
#
# ## explaination of this image
#
# 1.  Model complexity: model complexity denotes the number of features in the model where low stands for low number of features and high stands for higher number of feature
#
# 2. As we can see in the above image that the at lower number of feature we have very high prediction error and it goes down for the training sample with higher number of feature
#
# 3. Also we can see that how prediction error varies for the test sample which is higher to lower and then rises again
